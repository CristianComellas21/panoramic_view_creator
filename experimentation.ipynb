# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Load images.

# %%
# load images
images = []
for i in range(1, 4):
    img = cv2.imread(f'./images/parque{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    images.append(img)
    print(img.shape)
# Out:
# (3024, 4032, 3)
# (3024, 4032, 3)
# (3024, 4032, 3)

# %%
from algorithm import create_panoramic_view
res1, res2, final = create_panoramic_view(images, match_threshold=0.6, verbose=False)
plt.imshow(res1)
plt.show()
plt.imshow(res2)
plt.show()
plt.imshow(final)
# Out:
# bottom candidates: [array([9208.974, 4350.213], dtype=float32), array([13187.211 ,  6515.6646], dtype=float32), array([4032.        , 3283.78809824]), array([4032.        , 3286.03241214])]
# bottom limit: 3283.7880982442466
# top candidates: [array([ 8397.884 , -1612.2849], dtype=float32), array([16058.424, -5131.713], dtype=float32), array([4032.        , -431.52200858]), array([4032.        , -287.21494752])]
# top limit: -287.21494752323014

# %%
# Pint key points

for i in range(len(result['key_points'])):
    plt.figure()
    cv2.drawKeypoints(images[i], result['key_points'][i], images[i], color=(0, 255, 0), flags=0)
    plt.imshow(images[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/cris21/master/1_PRIMERO/Primer semestre/Computer vision and 3D Reconstruction/Project/Code/panoramic_view_creator/experimentation.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/cris21/master/1_PRIMERO/Primer%20semestre/Computer%20vision%20and%203D%20Reconstruction/Project/Code/panoramic_view_creator/experimentation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Pint key points
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/cris21/master/1_PRIMERO/Primer%20semestre/Computer%20vision%20and%203D%20Reconstruction/Project/Code/panoramic_view_creator/experimentation.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> for i in range(len(result['key_points'])):
# ...

# %%
# Plot good matches

plt.imshow(cv2.drawMatchesKnn(images[0], result['key_points'][1], images[1], result['key_points'][0], result['matches'], None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS))
