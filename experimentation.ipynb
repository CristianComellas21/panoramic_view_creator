# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %% [markdown]
# Load images.

# %%
# load images
images = []
for i in range(1, 3):
    img = cv2.imread(f'./images/edifici{i}.jpg')
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    images.append(img)

# %%
from algorithm import create_panoramic_view
result = create_panoramic_view(images, match_threshold=0.6)
plt.imshow(result)
# Out:
# Descriptors Left:  (2000, 32)
# Descriptors Right:  (2000, 32)
# Matches:  2000
# Good Matches:  45

# %%
print(result.shape)
# Out:
# (3000, 8000, 3)

# %%
# draw key points
for i in range(len(images)):
    img = images[i]
    for kp in key_points[i]:
        x, y = kp.pt
        cv2.circle(img, (int(x), int(y)), 5, (0, 0, 255), 1)

# plot images with key points
fig = plt.figure(figsize=(20, 10))
for i in range(len(images)):
    ax = fig.add_subplot(1, len(images), i + 1)
    ax.imshow(images[i])
    ax.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 for i in range(len(images)):
#       3     img = images[i]
# ----> 4     for kp in key_points[i]:
#       5         x, y = kp.pt
#       6         cv2.circle(img, (int(x), int(y)), 5, (0, 0, 255), 1)
#
# NameError: name 'key_points' is not defined
